# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import re

# %%
yearList = ["2011", "2012", "2013", "2014", "2015"]
weatherList = []

# %%
weatherTranslate = {
                        '晴': "clear",
                        '多云': "partly cloudy",
                        '雨夹雪': "sleet",
                        '阴': "cloudy",
                        '小雨': "light rain",
                        '小到中雪': "small to medium snow",
                        '小雪': "light snow",
                        '大雪': "heavy snow",
                        '中到大雪': "medium to heavy snow",
                        '中雨': "rain",
                        '阵雨': "shower",
                        '雷阵雨': "thunder storm",
                        '中到大雨': "medium to heavy rain",
                        '大雨': "heavy rain",
                        '大到暴雨': "heavy rain",
                        '小到中雨': "small to moderate rain",
                        '暴雨': "rainstorm",
                        '-': "n/a",
                        '雾': "fog",
                        '': "n/a"
                    }

# %%
def unique(list1): 
  
    unique_list = [] 
      
    for x in list1: 
        # check if exists in unique_list or not 
        if x not in unique_list: 
            unique_list.append(x) 
    return unique_list

# %%
for year in yearList:
    
    rows = []
    
    # all months
    for i in range(1, 13):

        if i < 10:
            m = "0" + str(i)
        else:
            m = "" + str(i)
    
        quote_page = 'http://www.tianqihoubao.com/lishi/shanghai/month/'+year+m+'.html'
        print(quote_page)
        page = urlopen(quote_page)


        soup = BeautifulSoup(page, 'html.parser', fromEncoding="gb2312")

        for row in soup.find_all('tr'):
            columns = []
            
            colCount = 0
            for val in row.find_all('td'):
                text = val.text.replace(" ", "").replace("\r", "").replace("\n", "")
                
                if colCount == 0:
                    text = text.replace('年', '-')
                    text = text.replace('月', '-')
                    text = text.replace('日', '')
                
                elif colCount == 1:
                    weatherDesc = text.split("/")
                    newWeatherDesc = []
                    if len(weatherDesc) == 2:
                        weatherList.append(weatherDesc[0])
                        weatherList.append(weatherDesc[1])
                        
                        newWeatherDesc.append(weatherTranslate[weatherDesc[0]])
                        newWeatherDesc.append(weatherTranslate[weatherDesc[1]])
                        
                        text = ",".join(newWeatherDesc)
                
                elif colCount == 2:
                    minMaxTemperature = list(map(int, re.findall(r'\d+', text)))
                    text = ",".join(str(v) for v in minMaxTemperature)
                    
                elif colCount == 3:
                    windSpeed = list(map(int, re.findall(r'\d+', text)))
                    
                    if len(windSpeed) == 0:
                        text = "0"
                    else:
                        text = str(max(windSpeed))
                        
                columns.append(text)
                

                colCount = colCount + 1
            
            # not include header
            if(len(columns) > 2):
                rows.append(columns)


    f = open("ScrapedWeather/"+year+".csv", 'w+')
    for row in rows:
        f.write("%s\n" % (",".join(row)))

    f.close()
# Out:
# http://www.tianqihoubao.com/lishi/shanghai/month/201101.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201102.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201103.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201104.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201105.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201106.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201107.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201108.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201109.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201110.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201111.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201112.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201201.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201202.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201203.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201204.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201205.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201206.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201207.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201208.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201209.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201210.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201211.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201212.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201301.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201302.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201303.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201304.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201305.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201306.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201307.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201308.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201309.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201310.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201311.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201312.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201401.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201402.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201403.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201404.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201405.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201406.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201407.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201408.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201409.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201410.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201411.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201412.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201501.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201502.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201503.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201504.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201505.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201506.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201507.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201508.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201509.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201510.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201511.html
# http://www.tianqihoubao.com/lishi/shanghai/month/201512.html

# %%
print(weatherList)
# Out:
# ['晴', '多云', '多云', '雨夹雪', '多云', '晴', '雨夹雪', '雨夹雪', '阴', '多云', '多云', '晴', '多云', '多云', '晴', '多云', '阴', '多云', '晴', '多云', '多云', '多云', '晴', '晴', '多云', '多云', '小雨', '小雨', '晴', '晴', '多云', '多云', '多云', '阴', '小到中雪', '小雪', '晴', '多云', '多云', '雨夹雪', '多云', '晴', '雨夹雪', '雨夹雪', '阴', '多云', '多云', '晴', '多云', '多云', '晴', '多云', '阴', '多云', '晴', '多云', '多云', '多云', '晴', '晴', '多云', '多云', '小雨', '小雨', '晴', '晴', '多云', '多云', '多云', '阴', '小到中雪', '小雪', '小雪', '大雪', '中到大雪', '小雪', '多云', '晴', '晴', '多云', '小雨', '多云', '晴', '晴', '晴', '多云', '阴', '阴', '晴', '晴', '晴', '阴', '晴', '晴', '多云', '晴', '晴', '晴', '小雨', '小雨', '小雨', '多云', '晴', '多云', '多云', '多云', '小雨', '中雨', '阴', '小雨', '小雨', '小雨', '小雪', '小雪', '多云', '阴', '晴', '多云', '多云', '多云', '多云', '阴', '多云', '小雨', '多云', '小雨', '晴', '晴', '多云', '多云', '小雨', '小雨', '中雨', '中雨', '阴', '阴', '多云', '多云', '晴', '晴', '晴', '多云', '晴', '晴', '晴', '多云', '多云', '多云', '小雨', '小雨', '小雨', '阵雨', '小雨', '小雨', '阴', '多云', '晴', '晴', '阴', '多云', '晴', '晴', '多云', '小雨', '小雨', '阴', '晴', '晴', '晴', '多云', '多云', '多云', '晴', '晴', '晴', '多云', '阴', '晴', '多云', '阵雨', '小雨', '阴', '阴', '多云', '多云', '晴', '晴', '晴', '阴', '阴', '阵雨', '阵雨', '阵雨', '小雨', '中雨', '小雨', '小雨', '多云', '晴', '多云', '多云', '多云', '晴', '晴', '晴', '多云', '晴', '晴', '晴', '阴', '多云', '晴', '晴', '晴', '晴', '晴', '多云', '多云', '阴', '小雨', '小雨', '阴', '晴', '晴', '晴', '晴', '多云', '小雨', '小雨', '阴', '多云', '多云', '多云', '多云', '多云', '阴', '多云', '多云', '晴', '阴', '多云', '多云', '多云', '多云', '雷阵雨', '雷阵雨', '多云', '多云', '多云', '阴', '晴', '晴', '晴', '晴', '晴', '晴', '阴', '阵雨', '阴', '多云', '晴', '多云', '多云', '晴', '晴', '晴', '多云', '雷阵雨', '阴', '多云', '晴', '多云', '晴', '多云', '雷阵雨', '阵雨', '多云', '多云', '多云', '雷阵雨', '阵雨', '阴', '多云', '多云', '多云', '多云', '多云', '多云', '多云', '多云', '多云', '晴', '多云', '多云', '雷阵雨', '雷阵雨', '雷阵雨', '多云', '阴', '多云', '晴', '晴', '多云', '多云', '多云', '多云', '多云', '多云', '晴', '晴', '多云', '晴', '晴', '晴', '晴', '多云', '阵雨', '阵雨', '阵雨', '中雨', '多云', '阴', '多云', '多云', '多云', '阴', '多云', '多云', '多云', '多云', '阴', '多云', '晴', '晴', '多云', '多云', '阴', '阵雨', '多云', '多云', '多云', '多云', '多云', '阴', '中到大雨', '中雨', '小雨', '小雨', '中雨', '阵雨', '小雨', '多云', '多云', '晴', '多云', '雷阵雨', '大雨', '大雨', '中雨', '阵雨', '阵雨', '阴', '阵雨', '阵雨', '雷阵雨', '大雨', '大到暴雨', '阵雨', '小雨', '阵雨', '阵雨', '雷阵雨', '大到暴雨', '大到暴雨', '小到中雨', '阴', '多云', '阵雨', '雷阵雨', '阵雨', '雷阵雨', '阴', '多云', '多云', '雷阵雨', '雷阵雨', '大雨', '大到暴雨', '阵雨', '多云', '多云', '多云', '雷阵雨', '阵雨', '雷阵雨', '阵雨', '雷阵雨', '雷阵雨', '阵雨', '多云', '雷阵雨', '多云', '多云', '多云', '雷阵雨', '雷阵雨', '雷阵雨', '雷阵雨', '多云', '多云', '多云', '多云', '雷阵雨', '阵雨', '阵雨', '阵雨', '阴', '阵雨', '阴', '阴', '阴', '阵雨', '阴', '阵雨', '阵雨', '阴', '雷阵雨', '多云', '阵雨', '阵雨', '阵雨', '阴', '多云', '多云', '阵雨', '阵雨', '雷阵雨', '多云', '多云', '多云', '雷阵雨', '多云', '多云', '多云', '雷阵雨', '多云', '多云', '多云', '雷阵雨', '多云', '多云', '多云', '多云', '晴', '晴', '晴', '晴', '晴', '雷阵雨', '多云', '雷阵雨', '多云', '雷阵雨', '多云', '雷阵雨', '雷阵雨', '雷阵雨', '阴', '多云', '多云', '阵雨', '暴雨', '中雨', '阵雨', '阵雨', '多云', '雷阵雨', '多云', '多云', '多云', '雷阵雨', '阵雨', '雷阵雨', '阵雨', '雷阵雨', '阵雨', '雷阵雨', '雷阵雨', '雷阵雨', '多云', '雷阵雨', '多云', '雷阵雨', '中雨', '雷阵雨', '阵雨', '雷阵雨', '多云', '多云', '阴', '雷阵雨', '雷阵雨', '中到大雨', '阵雨', '阵雨', '阵雨', '阵雨', '阵雨', '中雨', '阵雨', '中到大雨', '阵雨', '雷阵雨', '阴', '阴', '多云', '多云', '多云', '阵雨', '多云', '多云', '晴', '晴', '晴', '晴', '晴', '晴', '晴', '晴', '多云', '多云', '多云', '多云', '多云', '多云', '多云', '雷阵雨', '多云', '雷阵雨', '阵雨', '阵雨', '小雨', '阴', '多云', '多云', '多云', '多云', '多云', '多云', '晴', '多云', '晴', '多云', '多云', '多云', '阵雨', '多云', '多云', '多云', '阵雨', '阴', '小雨', '多云', '多云', '多云', '晴', '晴', '晴', '晴', '多云', '多云', '阴', '阵雨', '阵雨', '阴', '阴', '阴', '阴', '中雨', '中雨', '小雨', '阴', '阴', '小雨', '小雨', '阵雨', '阴', '阴', '多云', '阴', '阴', '多云', '多云', '多云', '晴', '晴', '晴', '晴', '多云', '多云', '阴', '阴', '多云', '多云', '多云', '阴', '小到中雨', '中雨', '小雨', '多云', '多云', '多云', '晴', '多云', '晴', '晴', '晴', '晴', '多云', '多云', '阴', '小雨', '小雨', '多云', '晴', '晴', '多云', '阵雨', '中雨', '小雨', '多云', '多云', '多云', '阴', '多云', '阴', '阴', '小雨', '小雨', '小雨', '多云', '多云', '多云', '多云', '多云', '阴', '阵雨', '阵雨', '阴', '阵雨', '阵雨', '阵雨', '阵雨', '小雨', '小雨', '阴', '阴', '小雨', '小雨', '小雨', '小雨', '小雨', '小雨', '多云', '多云', '多云', '多云', '晴', '晴', '多云', '多云', '多云', '多云', '多云', '多云', '小雨', '中雨', '阵雨', '阵雨', '阵雨', '小雨', '阴', '多云', '晴', '晴', '多云', '多云', '多云 ...

# %%
print(unique(weatherList))
# Out:
# ['晴', '多云', '雨夹雪', '阴', '小雨', '小到中雪', '小雪', '大雪', '中到大雪', '中雨', '阵雨', '雷阵雨', '中到大雨', '大雨', '大到暴雨', '小到中雨', '暴雨', '-', '雾']
